# %%
import psycopg2
conn = psycopg2.connect(dbname="otto", user="otto")
conn.autocommit = True
cursor = conn.cursor()
cursor.execute("CREATE TABLE notes(id integer PRIMARY KEY, body text, title text)")
conn.close()

# %%
from IPython.display import Image
Image("postgres.png")
